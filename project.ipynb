# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
colab_path = "/content/gdrive/MyDrive/yolov8_object_recognition"
os.chdir(colab_path)

# %%
# %cd /content/gdrive/MyDrive/yolov8_object_recognition
# Out:
# /content

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/yolov8_object_recognition

# %%
from IPython.display import Image

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 33.7 MB/s eta 0:00:00
# ...

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.4.0+cu121'

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/112.6 GB disk)

# %%
# !yolo task = detect mode = predict model = yolov8n.pt source = "https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 149MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 15.1MB/s]
# image 1/1 /content/gdrive/MyDrive/yolov8_object_recognition/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.2ms
# Speed: 11.9ms preprocess, 39.2ms inference, 692.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename = '/content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict/bus.jpg', width = 600)

# %%
# !yolo task = detect mode = predict model = yolov8x.pt source = "https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 225MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/gdrive/MyDrive/yolov8_object_recognition/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 90.1ms
# Speed: 2.6ms preprocess, 90.1ms inference, 763.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename = '/content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict2/bus.jpg', width = 600)

# %%
# !yolo task = detect mode = predict model = yolov8m.pt source = "bus.jpg" save_txt = True
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 178MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/yolov8_object_recognition/bus.jpg: 640x480 4 persons, 1 bus, 61.5ms
# Speed: 2.6ms preprocess, 61.5ms inference, 614.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename = '/content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict3/bus.jpg', width = 600)

# %%
# !cat /content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict3/labels/bus.txt
# Out:
# 5 0.497554 0.448424 0.991718 0.469683
# 0 0.183881 0.603899 0.243704 0.467903
# 0 0.912644 0.590421 0.173981 0.449443
# 0 0.350504 0.588737 0.150181 0.415487
# 0 0.0486078 0.657782 0.0964918 0.298765

# %%
# !yolo task = detect mode = predict model = yolov8s.pt source = "bus.jpg" hide_labels = True hide_conf = True
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in in the future. Please use 'show_conf' instead.
# ...
# 100% 21.5M/21.5M [00:00<00:00, 78.0MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/yolov8_object_recognition/bus.jpg: 640x480 4 persons, 1 bus, 39.6ms
# Speed: 2.9ms preprocess, 39.6ms inference, 872.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename = '/content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict4/bus.jpg', width = 600)

# %%
# !yolo task = detect mode = predict model = yolov8s.pt source = "bus.jpg" save_crop = True
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/yolov8_object_recognition/bus.jpg: 640x480 4 persons, 1 bus, 39.4ms
# Speed: 3.3ms preprocess, 39.4ms inference, 612.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename = '/content/gdrive/MyDrive/yolov8_object_recognition/runs/detect/predict5/crops/bus/bus.jpg', width = 600)
